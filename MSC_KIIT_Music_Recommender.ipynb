# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# id id
# artist artists
# name name
# popularity popularity
# danceability danceability
# energy energy
# key	key
# loudness loudness
# mode mode
# speechiness	speechiness
# acousticness acousticness
# instrumentalness instrumentalness
# liveness liveness
# valence valence
# tempo tempo
# duration_ms	duration_ms
# type explicit
#
# preview
# time_signature
# label

# %% [markdown]
# # **Data Normalization**

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/music_data.csv')
print(df.shape)
df.head()
# Out:
# (169909, 19)
#    acousticness                                   artists  ...  valence  year
# 0         0.995                       ['Carl Woitschach']  ...   0.7790  1928
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']  ...   0.0767  1928
# 2         0.604                   ['Seweryn Goszczyński']  ...   0.8800  1928
# 3         0.995                      ['Francisco Canaro']  ...   0.7200  1928
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']  ...   0.0693  1928
#
# [5 rows x 19 columns]

# %%
cols = ['artist','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms']
non_categorical = ['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms']
categorical = ['artist','key','mode']

# %ms = MinMaxScaler()
df[non_categorical] = df[non_categorical].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
# df[non_categorical] = mms.fit_transform(df[non_categorical])
df.head()
# Out:
#    acousticness                                   artists  ...  valence  year
# 0      0.998996                       ['Carl Woitschach']  ...   0.7790  1928
# 1      0.997992  ['Robert Schumann', 'Vladimir Horowitz']  ...   0.0767  1928
# 2      0.606426                   ['Seweryn Goszczyński']  ...   0.8800  1928
# 3      0.998996                      ['Francisco Canaro']  ...   0.7200  1928
# 4      0.993976  ['Frédéric Chopin', 'Vladimir Horowitz']  ...   0.0693  1928
#
# [5 rows x 19 columns]

# %% [markdown]
# # **Data Visualization**

# %%
corr = df[non_categorical].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col0,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col1,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col2,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col3,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col4,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col5,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col6,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row7_col7,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row8_col8,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col1{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col2{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col3{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col4{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col5,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col2,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row7_col6,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row8_col3{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col6,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col4,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col5,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col1,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col2,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col8,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col0,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col3,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row7_col9,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row9_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col7{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col8,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col7{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row0_col9,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col3,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col6,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row9_col3{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col0{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col2{
#             background-color:  #e16751;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col3{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col5{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col6{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col7{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col8{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row1_col9{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col0{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col1{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col3,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col7{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col4,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row8_col6{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col6,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row8_col9{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col7{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col8{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row2_col9,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row7_col3{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col0,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col4,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col2{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col1{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col2{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col5,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col7{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col6{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col8{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row3_col9,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row9_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col0{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col5{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col6{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row4_col9{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col1{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col4{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col7{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col8{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row5_col9,#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col3{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col0{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col1{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col4{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col5{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col8{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row6_col9{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0002row7_col0{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_2354296e_31a9_11ec_bfde_0242ac1c0

# %%
def cluster_plot(new_data):    
    kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
    pred_y = kmeans.fit_predict(new_data)
    t = [30,40,50,60,70,80,90]
    label_color = [t[i] for i in pred_y]
    plt.figure(figsize = (7,7))
    plt.scatter(new_data.iloc[:,0],new_data.iloc[:,1], c=label_color, alpha=0.5,cmap='viridis') 
    plt.show()

def silhouette(new_data):
    kmeans = KMeans(random_state=0)
    visualizer = KElbowVisualizer(kmeans, k=(2,11), metric='silhouette', timings=False)
    visualizer.fit(new_data)    
    visualizer.poof()

# %%
cluster_plot(df[non_categorical])

# %% [markdown]
# # **PCA (Principal Component Analysis)**

# %%
pca = PCA(0.95)
data = df.drop_duplicates()
data = pca.fit_transform(data[non_categorical])
cluster_plot(pd.DataFrame(data))
pd.DataFrame(data).head()
# Out:
#           0         1         2         3         4         5         6
# 0  0.576489 -0.138849  0.474513 -0.069667  0.019935 -0.047704 -0.007191
# 1  1.046452  0.464292  0.025553 -0.183309  0.087433 -0.053232 -0.032483
# 2  0.039141 -0.508134  0.181155 -0.168655  0.705307  0.412507  0.048128
# 3  0.736481  0.080262  0.628113 -0.164995  0.140678 -0.063648 -0.058877
# 4  0.964053  0.557558  0.003448 -0.041694 -0.045182  0.012866 -0.139625

# %%
data = pd.DataFrame(data)
#silhouette(data)

# %% [markdown]
# #### From the above graph we can determine that the clustering algorithm requires four clusters

# %% [markdown]
# # **Model Training**

# %%
def train(df_train):
    n = 1
    for _ in range(n):
        # train_df, test_df = train_test_split(df_train)
        km = KMeans(
            n_clusters=4, init='random',
            n_init=10, max_iter=1000, 
            tol=1e-04, random_state=0
        )
        y_km = km.fit(df_train)
        # km.labels_
        # km.predict(test_df)
    return km

def k_mean_distance(center_coordinates, data_coordiantes):
    summ=0
    mag=0
    for i in range(len(center_coordinates)):
        summ+=(center_coordinates[i]-data_coordiantes[i])**2
        mag+=(data_coordiantes[i])**2
    return (summ)*0.5

# %%
km = train(data)
data = pd.DataFrame(data)
# pickle.dump(km, open('KMeans_Clustering', 'wb'))
data['label'] = km.labels_
data['artists'] = df.artists
data['name'] = df.name
data['popularity'] = df.popularity
data['explicit'] = df.explicit
data.head()
# Out:
#           0         1  ...  popularity  explicit
# 0  0.576489 -0.138849  ...           0         0
# 1  1.046452  0.464292  ...           0         0
# 2  0.039141 -0.508134  ...           0         0
# 3  0.736481  0.080262  ...           0         0
# 4  0.964053  0.557558  ...           1         0
#
# [5 rows x 12 columns]

# %% [markdown]
# # **Genereating Outcome**

# %%
def song_recommendation(song,data):
    arr = []
    dummy_df = data.loc[data['label']==song.label.values[0]]
    print(len(dummy_df.values))
    for i in range(len(dummy_df.values)):
        if(i>51): break
        dist = k_mean_distance(dummy_df.values[i][0:7],song.values[0][0:7])
        arr.append((
            dummy_df.values[i][11]/(dist+0.00000001)**2,
            dist,
            dummy_df.values[i][11],
            dummy_df.values[i][8],
            dummy_df.values[i][9],
            dummy_df.values[i][10],
        ))
    arr.sort()
    return arr

def song_print(song):
    print('='*200)
    print('Artist:  ', song.artists.values[0])
    print('Song Name:   ', song.name.values[0])
    print('Type:   ', song['explicit'].values[0])
    print('='*200)

# %%
song = data.loc[[12980]]
ans = song_recommendation(song,data)
song_print(song)
j=1
for i in ans[::-1]:
    print('Number:  ', j)
    print('Popularity/distance:  ',i[0])
    print('Artist:  ', i[3])
    print('Song Name:   ', i[4])
    print('Type:   ', i[5])
    print('-'*100)
    j+=1
# Out:
# 74985
# ========================================================================================================================================================================================================
# Artist:   ['Camouflage']
# Song Name:    The Great Commandment
# Type:    0
# ========================================================================================================================================================================================================
# Number:   1
# Popularity/distance:   8.914802220093208
# Artist:   ['Shorty Bralik', 'ParkPlace Swagg']
# Song Name:    No Lack'n
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   2
# Popularity/distance:   3.6213644802090226
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 220.3 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   3
# Popularity/distance:   2.840136453712953
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 174.2 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   4
# Popularity/distance:   2.7839775107735583
# Artist:   ['Эрнест Хемингуэй']
# Song Name:    Часть 8.5 & Часть 9.1 - Старик и море
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   5
# Popularity/distance:   2.718934928242064
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 104.3 & Часть 105.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   6
# Popularity/distance:   2.6591006247498017
# Artist:   ['Эрнест Хемингуэй']
# Song Name:    Часть 9.2 - Старик и море
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   7
# Popularity/distance:   2.644179550308669
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 128.3 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   8
# Popularity/distance:   2.514434582111415
# Artist:   ['Эрнест Хемингуэй']
# Song Name:    Часть 17.2 - Старик и море
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   9
# Popularity/distance:   2.4460591219557775
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 156.5 & Часть 157.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   10
# Popularity/distance:   2.4345228058373882
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 169.3 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   11
# Popularity/distance:   2.392483017730352
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 35.4 & Часть 36.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   12
# Popularity/distance:   2.3849323604361325
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 17.2 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   13
# Popularity/distance:   2.3235506004538475
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 220.2 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   14
# Popularity/distance:   2.2710863593462176
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 188.4 & Часть 189.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   15
# Popularity/distance:   2.2115620475179645
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 222.2 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   16
# Popularity/distance:   2.1721726916723787
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 105.2 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   17
# Popularity/distance:   2.0906484276467845
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 190.3 & Часть 191.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   18
# Popularity/distance:   2.0774103628753777
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 99.4 & Часть 100.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   19
# Popularity/distance:   2.009645057202161
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 111.2 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   20
# Popularity/distance:   1.977173977419917
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 231.4 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   21
# Popularity/distance:   1.9223666099836239
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 141.3 & Часть 142.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   22
# Popularity/distance:   1.6606624657601736
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 124.2 & Часть 125.1 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   23
# Popularity/distance:   1.6595614931354852
# Artist:   ['Эрих Мария Ремарк']
# Song Name:    Часть 217.3 - Триумфальная арка
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   24
# Popularity/distance:   1.3487032328182635
# Artist:   ['Эрнест Хемингуэй']
# Song Name:    Часть 31.4 & Часть 32.1 - По ком звонит колокол
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   25
# Popularity/distance:   0.0
# Artist:   ['Federico García Lorca']
# Song Name:    Capítulo 4.6 & Capítulo 5.1 - la Casa de Bernarda Alba
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   26
# Popularity/distance:   0.0
# Artist:   ['Federico García Lorca']
# Song Name:    Capítulo 13.4 - la Casa de Bernarda Alba
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   27
# Popularity/distance:   0.0
# Artist:   ['Federico García Lorca']
# Song Name:    Capítulo 7.3 - la Casa de Bernarda Alba
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   28
# Popularity/distance:   0.0
# Artist:   ['Federico García Lorca']
# Song Name:    Capítulo 7.2 - la Casa de Bernarda Alba
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   29
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    'A discoteca - Musical base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   30
# Popularity/distance:   0.0
# Artist:   ['Marika Rossa', 'Alberto Ruiz']
# Song Name:    Back To The Old School ( V2 ) - Original Stick
# Type:    13
# ----------------------------------------------------------------------------------------------------
# Number:   31
# Popularity/distance:   0.0
# Artist:   ['Future Rapper']
# Song Name:    Strom Watcher
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   32
# Popularity/distance:   0.0
# Artist:   ['Shungi Music Crew']
# Song Name:    Trip to Limpopo
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   33
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    Caravan petrol - Musical base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   34
# Popularity/distance:   0.0
# Artist:   ['Male singers with marimba']
# Song Name:    Mayousse: Carnival Song
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   35
# Popularity/distance:   0.0
# Artist:   ['Unspecified']
# Song Name:    In the Gloaming
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   36
# Popularity/distance:   0.0
# Artist:   ['Jeff Stetson']
# Song Name:    Nowhere Street
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   37
# Popularity/distance:   0.0
# Artist:   ['Wardell Gray']
# Song Name:    Southside - Alternate 4
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   38
# Popularity/distance:   0.0
# Artist:   ['Émile Waldteufel', 'George and Madeleine Brown']
# Song Name:    Waldteufel: Skaters' Waltz
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   39
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    'O sole mio - Instrument and base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   40
# Popularity/distance:   0.0
# Artist:   ['Feliciano Brunelli Y Su Orquesta']
# Song Name:    Booguie del Burrito - Remastered
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   41
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    Palcoscenico - Instrument and base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   42
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    'A sunnambula - Instrument and base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   43
# Popularity/distance:   0.0
# Artist:   ['The Cotton Candy Blues Band']
# Song Name:    Key to the highway
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   44
# Popularity/distance:   0.0
# Artist:   ['Shiny Gnomes']
# Song Name:    The Nest
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   45
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    Agata - Instrument and base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   46
# Popularity/distance:   0.0
# Artist:   ['Unspecified']
# Song Name:    Australia: Australian Aborigines - Corroborree Song
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   47
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    A città 'e pullecenella - Instrument and base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   48
# Popularity/distance:   0.0
# Artist:   ['Orchestra Studio 7']
# Song Name:    Tarantella luciana - Musical base Version
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   49
# Popularity/distance:   0.0
# Artist:   ['Billy Joe Shaver']
# Song Name:    Georgia On A Fast Train
# Type:    0
# ----------------------------------------------------------------------------------------------------
# Number:   50
# Popularity/distance:   0.0
# Artist:   ['Mina']
# Song Name:    Stringimi forte i polsi
# Type:    1
# ----------------------------------------------------------------------------------------------------
# Number:   51
# Popularity/distance:   0.0
# Artist:   ['Ansambl Biljana']
# Song Name:    Čifte Čifte Pajtonlari
# Type:    5
# ----------------------------------------------------------------------------------------------------
# Number:   52
# Popularity/distance:   0.0
# Artist:   ['Richard Levitt', 'Charles Byrd', 'Carl Tucker']
# Song Name:    Everybody's Got a Little Devil in Their Soul
# Type:    0
# ----------------------------------------------------------------------------------------------------
